# %% [markdown]
# # Merge Master Table
# Notebook di merging della master table (ottenuta nel Notebook 1) con i dataset provenienti da Italia Domani

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
master_table = pd.read_csv("data/updated/master_table_base.csv", sep=";")
# Out:
# /var/folders/2c/394jj2r140x4jgq0vzwn32680000gn/T/ipykernel_4242/2852483169.py:3: DtypeWarning: Columns (12,13,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   master_table = pd.read_csv("data/updated/master_table_base.csv", sep=";")

# %% [markdown]
# # Indicatori

# %%
indicators = pd.read_parquet("data/updated/indicators.parquet")

master_table_ID = master_table.merge(
    indicators,
    how='left',
    left_on='Codice Univoco Submisura',
    right_on='Codice Univoco Submisura'
)
master_table_ID = master_table_ID.drop_duplicates()
print(master_table_ID.shape)
# Out:
# (760379, 41)

# %%
master_table_ID.columns
# Out:
# Index(['Unnamed: 0', 'CIG', 'CUP', 'Regione', 'provincia', 'Comune',
#        'importo_complessivo_gara', 'CLASSE_IMPORTO', 'Descrizione Missione_x',
#        'Missione_x', 'Componente_x', 'cod_mis_premiale', 'misura_premiale',
#        'CATEGORIA', 'flag_quote', 'quota_femminile', 'quota_giovanile',
#        'cod_mot_deroga', 'mot_deroga', 'data_pubblicazione',
#        'anno_pubblicazione', 'FLAG_URGENZA', 'MOTIVO_URGENZA', 'ESITO',
#        'Codice Univoco Submisura', 'Programma', 'Missione_y',
#        'Descrizione Missione_y', 'Componente_y', 'Descrizione Componente',
#        'ID Misura', 'Codice Univoco Misura', 'Descrizione Misura',
#        'ID Submisura', 'Codice CID', 'Descrizione Submisura',
#        'Amministrazione Titolare', 'Codice Indicatore',
#        'Descrizione Indicatore', 'Unità di misura', 'Stock/Flusso'],
#       dtype='object')

# %%
colonne = [
    'CIG', 
    'CUP', 
    'Regione', 
    'provincia', 
    'Comune',
    'importo_complessivo_gara', 
    'CLASSE_IMPORTO', 
    'Missione_x', 
    'Descrizione Missione_x',
    'Componente_x',
    'cod_mis_premiale', 
    'misura_premiale',
    'CATEGORIA', 
    'flag_quote', 
    'quota_femminile', 
    'quota_giovanile',
    'cod_mot_deroga', 
    'mot_deroga', 
    'data_pubblicazione',
    'anno_pubblicazione', 
    'FLAG_URGENZA', 
    'MOTIVO_URGENZA', 
    'ESITO',
    'Codice Univoco Submisura', 
    'Programma',
    'Descrizione Componente',
    'ID Misura', 
    'Codice Univoco Misura', 
    'Descrizione Misura',
    'ID Submisura', 
    'Codice CID', 
    'Descrizione Submisura',
    'Amministrazione Titolare', 
    'Codice Indicatore',
    'Descrizione Indicatore', 
    'Unità di misura', 
    'Stock/Flusso'
]

# %%
master_table_ID = master_table_ID[colonne]

# %%
master_table_ID.head()
# Out:
#           CIG              CUP Regione provincia Comune  \
# 0  9708946BB0  D28I21000110001     NaN   CASERTA    NaN
# 1  9708946BB0  D28I21000110001     NaN   CASERTA    NaN
# 2  9708946BB0  D28I21000110001     NaN   CASERTA    NaN
# 3  9737176BD2  J91B22000660001     NaN      PISA    NaN
# 4  9601726AF2  E86F22000100001     NaN   PESCARA    NaN
#
#    importo_complessivo_gara CLASSE_IMPORTO Missione_x Descrizione Missione_x  \
# 0                   7280.00          BASSA         M5  Inclusione e coesione
# 1                   7280.00          BASSA         M5  Inclusione e coesione
# 2                   7280.00          BASSA         M5  Inclusione e coesione
# 3                   1681.84          BASSA        NaN                    NaN
# 4                  36720.87          BASSA        NaN                    NaN
#
#   Componente_x  cod_mis_premiale misura_premiale CATEGORIA flag_quote  \
# 0         M5C2               NaN             NaN       NaN          N
# 1         M5C2               NaN             NaN       NaN          N
# 2         M5C2               NaN             NaN       NaN          N
# 3          NaN               NaN             NaN       NaN          N
# 4          NaN               NaN             NaN       NaN          N
#
#    quota_femminile  quota_giovanile  cod_mot_deroga  \
# 0              NaN              NaN             1.0
# 1              NaN              NaN             6.0
# 2              NaN              NaN             7.0
# 3              NaN              NaN             1.0
# 4              NaN              NaN             8.0
#
#                                           mot_deroga data_pubblicazione  \
# 0                      IMPORTO RIDOTTO DEL CONTRATTO         2023-01-23
# 1  NECESSITÀ DI ESPERIENZA O DI PARTICOLARI ABILI...         2023-01-23
# 2  ASSUNZIONE DI UN NUMERO DI LAVORATORI INFERIOR...         2023-01-23
# 3                      IMPORTO RIDOTTO DEL CONTRATTO         2023-01-17
# 4                                              ALTRO         2023-01-13
#
#    anno_pubblicazione  FLAG_URGENZA MOTIVO_URGENZA        ESITO  \
# 0                2023             0            NaN          NaN
# 1                2023             0            NaN          NaN
# 2                2023             0            NaN          NaN
# 3                2023             0            NaN  AGGIUDICATA
# 4                2023             0            NaN  AGGIUDICATA
#
#   Codice Univoco Submisura Programma  \
# 0             M5C2I2.01.00      PNRR
# 1             M5C2I2.01.00      PNRR
# 2             M5C2I2.01.00      PNRR
# 3                      NaN       NaN
# 4                      NaN       NaN
#
#                               Descrizione Componente ID Misura  \
# 0  Infrastrutture sociali, famiglie, comunità e t...  M5C2I2.1
# 1  Infrastrutture sociali, famiglie, comunità e t...  M5C2I2.1
# 2  Infrastrutture sociali, famiglie, comunità e t...  M5C2I2.1
# 3                                                NaN       NaN
# 4                                                NaN       NaN
#
#   Codice Univoco Misura                                 Descrizione Misura  \
# 0             M5C2I2.01  Investimenti in progetti di rigenerazione urba...
# 1             M5C2I2.01  Investimenti in progetti di rigenerazione urba...
# 2             M5C2I2.01  Investimenti in progetti di rigenerazione urba...
# 3                   NaN                                                NaN
# 4                   NaN                                                NaN
#
#   ID Submisura Codice CID                              Descrizione Submisura  \
# 0     M5C2I2.1     M5C2I4  Investimenti in progetti di rigenerazione urba...
# 1     M5C2I2.1     M5C2I4  Investimenti in progetti di rigenerazione urba...
# 2     M5C2I2.1     M5C2I4  Investimenti in progetti di rigenerazione urba...
# 3          NaN        NaN                                                NaN
# 4          NaN        NaN                                                NaN
#
#   Amministrazione Titolare Codice Indicatore  \
# 0   MINISTERO DELL'INTERNO                C1
# 1   MINISTERO DELL'INTERNO                C1
# 2   MINISTERO DELL'INTERNO                C1
# 3                      NaN               NaN
# 4                      NaN               NaN
#
#                            Descrizione Indicatore Unità di misura Stock/Flusso
# 0  RISPARMI SUL CONSUMO ANNUO DI ENERGIA PRIMARIA        MWh/anno        Stock
# 1  RISPARMI SUL CONSUMO ANNUO DI ENERGIA PRIMARIA        MWh/anno        Stock
# 2  RISPARMI SUL CONSUMO ANNUO DI ENERGIA PRIMARIA        MWh/anno        Stock
# 3                                             NaN             NaN          NaN
# 4                                             NaN             NaN          NaN

# %%
master_table_ID.to_parquet('data/helpers/master_ID1.parquet')

# %% [markdown]
# ## Indicatori SDG

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

master_table_ID = pd.read_parquet('data/helpers/master_ID1.parquet')
indicatori_sdg = pd.read_parquet("data/updated/indicators_sdg.parquet")

master_table_ID = master_table_ID.merge(
    indicatori_sdg,
    how='left',
    left_on='Codice Univoco Submisura',
    right_on='COD_SUB_MISURA'
)
master_table_ID = master_table_ID.drop_duplicates()
print(master_table_ID.shape)
# Out:
# (850534, 63)

# %%
colonne = [
    'CIG', 
    'CUP', 
    'Regione', 
    'provincia', 
    'Comune',
    'importo_complessivo_gara', 
    'CLASSE_IMPORTO', 
    'Missione_x', 
    'Descrizione Missione_x',
    'Componente_x',
    'DES_COMPONENTE',
    'cod_mis_premiale', 
    'misura_premiale',
    'CATEGORIA', 
    'flag_quote', 
    'quota_femminile', 
    'quota_giovanile',
    'cod_mot_deroga', 
    'mot_deroga', 
    'data_pubblicazione',
    'anno_pubblicazione', 
    'FLAG_URGENZA', 
    'MOTIVO_URGENZA', 
    'ESITO',
    'Codice Univoco Submisura', 
    'Programma',
    'COD_MISURA',
    'Codice Univoco Misura', 
    'DES_MISURA',
    'DES_LIVELLO',
    'ID Submisura', 
    'Codice CID', 
    'Descrizione Submisura',
    'Amministrazione Titolare', 
    'Codice Indicatore',
    'Descrizione Indicatore', 
    'Unità di misura', 
    'Stock/Flusso',
    'IMPORTO',
    'DES_INVESTIMENTO',
    'DES_PRESTITO',
    'DES_AMMINISTRAZIONE',
    'PREVALENTE',
    'INDICATORE',
    'DES_INDICATORE',
    'DES_INDAGINE',
    'NOTA',
    'DES_FONTE',
    'DES_UNITA',
    'GOAL',
    'DES_GOAL',
    'TARGET',
    'DES_TARGET',
    'INDICATOR',
    'DES_INDICATOR'
]

# %%
master_table_ID = master_table_ID[colonne]
master_table_ID.shape
# Out:
# (850534, 55)

# %%
master_table_ID.head()
# Out:
#           CIG              CUP Regione provincia Comune  \
# 0  9708946BB0  D28I21000110001    None   CASERTA   None
# 1  9708946BB0  D28I21000110001    None   CASERTA   None
# 2  9708946BB0  D28I21000110001    None   CASERTA   None
# 3  9737176BD2  J91B22000660001    None      PISA   None
# 4  9601726AF2  E86F22000100001    None   PESCARA   None
#
#    importo_complessivo_gara CLASSE_IMPORTO Missione_x Descrizione Missione_x  \
# 0                   7280.00          BASSA         M5  Inclusione e coesione
# 1                   7280.00          BASSA         M5  Inclusione e coesione
# 2                   7280.00          BASSA         M5  Inclusione e coesione
# 3                   1681.84          BASSA       None                   None
# 4                  36720.87          BASSA       None                   None
#
#   Componente_x                                     DES_COMPONENTE  \
# 0         M5C2  Infrastrutture sociali, famiglie, comunità e t...
# 1         M5C2  Infrastrutture sociali, famiglie, comunità e t...
# 2         M5C2  Infrastrutture sociali, famiglie, comunità e t...
# 3         None                                                NaN
# 4         None                                                NaN
#
#    cod_mis_premiale misura_premiale CATEGORIA flag_quote  quota_femminile  \
# 0               NaN            None      None          N              NaN
# 1               NaN            None      None          N              NaN
# 2               NaN            None      None          N              NaN
# 3               NaN            None      None          N              NaN
# 4               NaN            None      None          N              NaN
#
#    quota_giovanile  cod_mot_deroga  \
# 0              NaN             1.0
# 1              NaN             6.0
# 2              NaN             7.0
# 3              NaN             1.0
# 4              NaN             8.0
#
#                                           mot_deroga data_pubblicazione  \
# 0                      IMPORTO RIDOTTO DEL CONTRATTO         2023-01-23
# 1  NECESSITÀ DI ESPERIENZA O DI PARTICOLARI ABILI...         2023-01-23
# 2  ASSUNZIONE DI UN NUMERO DI LAVORATORI INFERIOR...         2023-01-23
# 3                      IMPORTO RIDOTTO DEL CONTRATTO         2023-01-17
# 4                                              ALTRO         2023-01-13
#
#    anno_pubblicazione  FLAG_URGENZA MOTIVO_URGENZA        ESITO  \
# 0                2023             0           None         None
# 1                2023             0           None         None
# 2                2023             0           None         None
# 3                2023             0           None  AGGIUDICATA
# 4                2023             0           None  AGGIUDICATA
#
#   Codice Univoco Submisura Programma COD_MISURA Codice Univoco Misura  \
# 0             M5C2I2.01.00      PNRR  M5C2I2.01             M5C2I2.01
# 1             M5C2I2.01.00      PNRR  M5C2I2.01             M5C2I2.01
# 2             M5C2I2.01.00      PNRR  M5C2I2.01             M5C2I2.01
# 3                     None      None        NaN                  None
# 4                     None      None        NaN                  None
#
#                                           DES_MISURA DES_LIVELLO ID Submisura  \
# 0  Investimenti in progetti di rigenerazione urba...      Misura     M5C2I2.1
# 1  Investimenti in progetti di rigenerazione urba...      Misura     M5C2I2.1
# 2  Investimenti in progetti di rigenerazione urba...      Misura     M5C2I2.1
# 3                                                NaN         NaN         None
# 4                                                NaN         NaN         None
#
#   Codice CID                              Descrizione Submisura  \
# 0     M5C2I4  Investimenti in progetti di rigenerazione urba...
# 1     M5C2I4  Investimenti in progetti di rigenerazione urba...
# 2     M5C2I4  Investimenti in progetti di rigenerazione urba...
# 3       None                                               None
# 4       None                                               None
#
#   Amministrazione Titolare Codice Indicatore  \
# 0   MINISTERO DELL'INTERNO                C1
# 1   MINISTERO DELL'INTERNO                C1
# 2   MINISTERO DELL'INTERNO                C1
# 3                     None              None
# 4                     None              None
#
#                            Descrizione Indicatore Unità di misura  \
# 0  RISPARMI SUL CONSUMO ANNUO DI ENERGIA PRIMARIA        MWh/anno
# 1  RISPARMI SUL CONSUMO ANNUO DI ENERGIA PRIMARIA        MWh/anno
# 2  RISPARMI SUL CONSUMO ANNUO DI ENERGIA PRIMARIA        MWh/anno
# 3                                            None            None
# 4                                            None            None
#
#   Stock/Flusso         IMPORTO DES_INVESTIMENTO DES_PRESTITO  \
# 0        Stock  3300000000,00      Investimento     Prestito
# 1        Stock  3300000000,00      Investimento     Prestito
# 2        Stock  3300000000,00      Investimento     Prestito
# 3         None             NaN              NaN          NaN
# 4         None             NaN              NaN          NaN
#
#       DES_AMMINISTRAZIONE PREVALENTE INDICATORE  \
# 0  Ministero dell'Interno         si   07SIC021
# 1  Ministero dell'Interno         si   07SIC021
# 2  Ministero dell'Interno         si   07SIC021
# 3                     NaN        NaN        NaN
# 4                     NaN        NaN        NaN
#
#                                       DES_INDICATORE  \
# 0  Presenza di elementi di degrado nella zona in ...
# 1  Presenza di elementi di degrado nella zona in ...
# 2  Presenza di elementi di degrado nella zona in ...
# 3                                                NaN
# 4                                                NaN
#
#                              DES_INDAGINE  \
# 0  Indagine Aspetti della vita quotidiana
# 1  Indagine Aspetti della vita quotidiana
# 2  Indagine Aspetti della vita quotidiana
# 3                                     NaN
# 4                                     NaN
#
#                                                 NOTA DES_FONTE  \
# 0  A partire dal 2020 per l'intera serie storica ...     Istat
# 1  A partire dal 2020 per l'intera serie storica ...     Istat
# 2  A partire dal 2020 per l'intera serie storica ...     Istat
# 3                                                NaN       NaN
# 4                                                NaN       NaN
#
#             DES_UNITA  GOAL  \
# 0  Valori percentuali  11.0
# 1  Valori percentuali  11.0
# 2  Valori percentuali  11.0
# 3                 NaN   NaN
# 4                 NaN   NaN
#
#                                             DES_GOAL TARGET DES_TARGET  \
# 0  Rendere le città e gli insediamenti umani incl...   None       None
# 1  Rendere le città e gli insediamenti umani incl...   None       None
# 2  Rendere le città e gli insediamenti umani incl...   None       None
# 3                                                NaN    NaN        NaN
# 4                                                NaN    NaN        NaN
#
#   INDICATOR DES_INDICATOR
# 0      None          None
# 1      None          None
# 2      None          None
# 3       NaN           NaN
# 4       NaN           NaN

# %%
master_table_ID.to_parquet('data/helpers/master_ID2.parquet')

# %% [markdown]
# ## Targets

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

master_table_ID = pd.read_parquet('data/helpers/master_ID2.parquet')
targets = pd.read_parquet("data/updated/targets.parquet")

master_table_ID = master_table_ID.merge(
    targets,
    how='left',
    left_on='CUP',
    right_on='CUP'
)
master_table_ID = master_table_ID.drop_duplicates()
print(master_table_ID.shape)
# Out:
# (1377562, 67)

# %%
colonne = [
    'CIG', 
    'CUP', 
    'Regione', 
    'provincia', 
    'Comune',
    'importo_complessivo_gara', 
    'CLASSE_IMPORTO', 
    'Missione_x', 
    'Descrizione Missione_x',
    'Componente_x',
    'DES_COMPONENTE',
    'cod_mis_premiale', 
    'misura_premiale',
    'CATEGORIA', 
    'flag_quote', 
    'quota_femminile', 
    'quota_giovanile',
    'cod_mot_deroga', 
    'mot_deroga', 
    'data_pubblicazione',
    'anno_pubblicazione', 
    'FLAG_URGENZA', 
    'MOTIVO_URGENZA', 
    'ESITO',
    'Codice Univoco Submisura_x', 
    'Programma',
    'COD_MISURA',
    'Codice Univoco Misura', 
    'DES_MISURA',
    'DES_LIVELLO',
    'ID Submisura', 
    'Codice CID', 
    'Descrizione Submisura_x',
    'Amministrazione Titolare', 
    'Codice Indicatore_x',
    'Descrizione Indicatore_x', 
    'Unità di misura', 
    'Descrizione Unità di Misura',
    'Stock/Flusso',
    'IMPORTO',
    'DES_INVESTIMENTO',
    'DES_PRESTITO',
    'DES_AMMINISTRAZIONE',
    'PREVALENTE',
    'INDICATORE',
    'DES_INDICATORE',
    'DES_INDAGINE',
    'NOTA',
    'DES_FONTE',
    'DES_UNITA',
    'GOAL',
    'DES_GOAL',
    'TARGET',
    'DES_TARGET',
    'INDICATOR',
    'DES_INDICATOR',
    'Codice Locale Progetto',
    'Valore Programmato',
    'Valore Realizzato',
    'Mese',
    'Anno',
    'Data di Aggiornamento'
]

# %%
master_table_ID = master_table_ID[colonne]
master_table_ID.shape
# Out:
# (1377562, 62)

# %%
master_table_ID.to_parquet('data/helpers/master_ID3.parquet')

# %% [markdown]
# ## Universo Regis

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

master_table_ID = pd.read_parquet('data/helpers/master_ID3.parquet')
indicatori_com_regis = pd.read_parquet("data/updated/universo_regis.parquet")

# %%
master_table_ID.shape
# Out:
# (1130060, 62)

# %%
master_table_ID.columns
# Out:
# Index(['CIG', 'CUP', 'Regione', 'provincia', 'Comune',
#        'importo_complessivo_gara', 'CLASSE_IMPORTO', 'Missione_x',
#        'Descrizione Missione_x', 'Componente_x', 'DES_COMPONENTE',
#        'cod_mis_premiale', 'misura_premiale', 'CATEGORIA', 'flag_quote',
#        'quota_femminile', 'quota_giovanile', 'cod_mot_deroga', 'mot_deroga',
#        'data_pubblicazione', 'anno_pubblicazione', 'FLAG_URGENZA',
#        'MOTIVO_URGENZA', 'ESITO', 'Codice Univoco Submisura_x', 'Programma',
#        'COD_MISURA', 'Codice Univoco Misura', 'DES_MISURA', 'DES_LIVELLO',
#        'ID Submisura', 'Codice CID', 'Descrizione Submisura_x',
#        'Amministrazione Titolare', 'Codice Indicatore_x',
#        'Descrizione Indicatore_x', 'Unità di misura',
#        'Descrizione Unità di Misura', 'Stock/Flusso', 'IMPORTO',
#        'DES_INVESTIMENTO', 'DES_PRESTITO', 'DES_AMMINISTRAZIONE', 'PREVALENTE',
#        'INDICATORE', 'DES_INDICATORE', 'DES_INDAGINE', 'NOTA', 'DES_FONTE',
#        'DES_UNITA', 'GOAL', 'DES_GOAL', 'TARGET', 'DES_TARGET', 'INDICATOR',
#        'DES_INDICATOR', 'Codice Locale Progetto', 'Valore Programmato',
#        'Valore Realizzato', 'Mese', 'Anno', 'Data di Aggiornamento'],
#       dtype='object')

# %%
master_table_ID['Codice Indicatore_x']
# Out:
# 0          None
# 1          None
# 2          None
# 3          None
# 4           C12
#            ...
# 1130055    None
# 1130056    None
# 1130057     C13
# 1130058     C13
# 1130059     C13
# Name: Codice Indicatore_x, Length: 1130060, dtype: object

# %%
master_table_ID['Anno'].isna().sum()
# Out:
# 475894

# %%
master_table_ID['CUP'].nunique()
# Out:
# 97153

# %%
indicatori_com_regis['CUP'].nunique()
# Out:
# 213423

# %%
indicatori_com_regis.shape
# Out:
# (906676, 17)

# %%
indicatori_com_regis.columns
# Out:
# Index(['Codice Univoco Submisura', 'Descrizione Submisura', 'CUP',
#        'Codice Locale Progetto', 'Codice Indicatore', 'Descrizione Indicatore',
#        'Unità di Misura', 'Descrizione Unità di Misura',
#        'Descrizione Tipo Indicatore', 'Valore Programmato',
#        'Valore Realizzato', 'Mese', 'Anno', 'Data di Estrazione',
#        'Progetto Validato', 'FLG_INDICATORI_PERSONE', 'FLG_INDICATORI_GENERE'],
#       dtype='object')

# %%
indicatori_com_regis['FLG_INDICATORI_GENERE']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 906671    0
# 906672    0
# 906673    0
# 906674    0
# 906675    0
# Name: FLG_INDICATORI_GENERE, Length: 906676, dtype: int64

# %%
indicatori_com_regis['FLG_INDICATORI_GENERE'].nunique()
# Out:
# 2

# %%
indicatori_com_regis['FLG_INDICATORI_GENERE'].isna().sum()
# Out:
# 0

# %%
indicatori_com_regis.dropna
# Out:
#        Unità di Misura           Anno  FLG_INDICATORI_PERSONE  \
# count    906676.000000  287809.000000           906676.000000
# mean          4.605877    2021.063156                0.762335
# std           1.847284      58.269133                0.425653
# min           1.000000       0.000000                0.000000
# 25%           4.000000    2022.000000                1.000000
# 50%           4.000000    2023.000000                1.000000
# 75%           6.000000    2023.000000                1.000000
# max           9.000000    2026.000000                1.000000
#
#        FLG_INDICATORI_GENERE
# count          906676.000000
# mean                0.331559
# std                 0.470774
# min                 0.000000
# 25%                 0.000000
# 50%                 0.000000
# 75%                 1.000000
# max                 1.000000

# %%
cols_to_drop = [
    'Codice Univoco Submisura', 
    'Descrizione Submisura', 
    'Codice Indicatore', 
    'Descrizione Indicatore',
    'Unità di Misura', 
    'Descrizione Unità di Misura',
    'Descrizione Tipo Indicatore', 
    'Mese', 
    'Anno', 
    'Data di Estrazione'
]

# %%
indicatori_com_regis.drop(columns=cols_to_drop, inplace=True)
indicatori_com_regis.shape
# Out:
# (906676, 7)

# %%
master_table_ID = master_table_ID.merge(
    indicatori_com_regis,
    how='left',
    left_on='CUP',
    right_on='CUP'
)
master_table_ID = master_table_ID.drop_duplicates()
print(master_table_ID.shape)
